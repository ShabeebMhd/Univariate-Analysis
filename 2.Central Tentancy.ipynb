# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
Quan=["ssc_p","hsc_p","degree_p","etest_p","mba_p","salary"]
Qual=["gender","ssc_b","hsc_b","hsc_s"<"degree_t"]

# %%
# the idea to secticate the Quan and Qual

#if variable== 'object':
    #print("Qual")
#else:
    #print("Quan")

# %%
dataset.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
dataset["gender"].dtypes
# Out:
# dtype('O')

# %%
dataset["ssc_p"].dtypes
# Out:
# dtype('float64')

# %%
if dataset["gender"].dtypes=='O':
    print("Qual")
else:
    print("Quan")
# Out:
# Qual

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
for column in dataset.columns:
    if dataset[column].dtypes=='O':
        print("Qual")
    else:
        print("Quan")
# Out:
# Quan
# Qual
# Quan
# Qual
# Quan
# Qual
# Qual
# Quan
# Qual
# Qual
# Quan
# Qual
# Quan
# Qual
# Quan

# %%
qual=[]
quan=[]

for column in dataset.columns:
    if dataset[column].dtypes=='O':
        #print("Qual")
        qual.append(column)
    else:
        #print("Quan")
        quan.append(column)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
def QuanQual(dataset):
    qual=[]
    quan=[]
    
    for column in dataset.columns:
        if dataset[column].dtypes=='O':
            #print("Qual")
            qual.append(column)
        else:
            #print("Quan")
            quan.append(column)
    return quan, qual

# %%
QuanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
Quan,Qual=QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Central Tendency

# %%
dataset["ssc_p"].mean()
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()
# Out:
# np.float64(67.0)

# %%
dataset["ssc_p"].mode()[0]
# Out:
# np.float64(62.0)

# %%
dataset["ssc_p"].mode()
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame()

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"])

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [Mean, Median, Mode]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=Quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["ssc_p"]["Mean"]=dataset["ssc_p"].mean()

# %%
descriptive
# Out:
#        sl_no      ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN  67.303395   NaN      NaN     NaN   NaN    NaN
# Median   NaN        NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN        NaN   NaN      NaN     NaN   NaN    NaN

# %%
for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    NaN        NaN        NaN        NaN        NaN        NaN
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median            NaN
# Mode              NaN

# %%
for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode              NaN

# %%
for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %%
import numpy as np

# %%
np.percentile(dataset["ssc_p"][0],10)
# Out:
# np.float64(67.0)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%"],columns=Quan)

for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=Quan)

for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]= descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"] = descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"] = dataset[columnName].min()
    descriptive[columnName]["Max"] = dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89       37.0       50.0       50.0      51.21
# ...

# %%
2>3
# Out:
# False

# %%
descriptive["hsc_p"]["Lesser"]>descriptive["hsc_p"]["Min"]
# Out:
# np.True_

# %%
LesserOut=[]
GreaterOut=[]

for columnName in Quan:
    if(descriptive[columnName]["Lesser"]>descriptive[columnName]["Min"]):
        LesserOut.append(columnName)

    if(descriptive[columnName]["Greater"]<descriptive[columnName]["Max"]):
        GreaterOut.append(columnName)

# %%
LesserOut
# Out:
# ['hsc_p']

# %%
GreaterOut
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
for columnName in LesserOut:
    dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]

for columnName in GreaterOut:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=Quan)

for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]= descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"] = descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"] = dataset[columnName].min()
    descriptive[columnName]["Max"] = dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
LesserOut=[]
GreaterOut=[]

for columnName in Quan:
    if(descriptive[columnName]["Lesser"]>descriptive[columnName]["Min"]):
        LesserOut.append(columnName)

    if(descriptive[columnName]["Greater"]<descriptive[columnName]["Max"]):
        GreaterOut.append(columnName)

# %%
LesserOut
# Out:
# []

# %%
GreaterOut
# Out:
# []

# %%
dataset["ssc_p"].value_counts()
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 73.00     9
# 52.00     9
#          ..
# 55.68     1
# 41.00     1
# 83.33     1
# 43.00     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freeqTable=pd.DataFrame(columns=["Unique_Values", "Frequency", "Relative_Frequency", "Clumsum"])

# %%
freeqTable["Unique_Values"]=dataset["hsc_p"].value_counts().index
freeqTable["Frequency"]=dataset["hsc_p"].value_counts().values
freeqTable["Relative_Frequency"]=freeqTable["Frequency"]/91
freeqTable["Clumsum"]=freeqTable["Relative_Frequency"].cumsum()

# %%
freeqTable
# Out:
#     Unique_Values  Frequency  Relative_Frequency   Clumsum
# 0           63.00         14            0.153846  0.153846
# 1           62.00         12            0.131868  0.285714
# 2           67.00          9            0.098901  0.384615
# 3           60.00          9            0.098901  0.483516
# 4           70.00          8            0.087912  0.571429
# ..            ...        ...                 ...       ...
# 86          65.50          1            0.010989  2.318681
# 87          77.60          1            0.010989  2.329670
# 88          70.20          1            0.010989  2.340659
# 89          61.40          1            0.010989  2.351648
# 90          61.33          1            0.010989  2.362637
#
# [91 rows x 4 columns]

# %%
def freeqTable(dataset,columnName):
    freeqTable=pd.DataFrame(columns=["Unique_Values", "Frequency", "Relative_Frequency", "Clumsum"])
    freeqTable["Unique_Values"]=dataset[columnName].value_counts().index
    freeqTable["Frequency"]=dataset[columnName].value_counts().values
    freeqTable["Relative_Frequency"]=freeqTable["Frequency"]/91
    freeqTable["Clumsum"]=freeqTable["Relative_Frequency"].cumsum()
    return freeqTable

# %%
freeqTable(dataset,"ssc_p")
# Out:
#      Unique_Values  Frequency  Relative_Frequency   Clumsum
# 0            62.00         11            0.120879  0.120879
# 1            63.00         10            0.109890  0.230769
# 2            67.00          9            0.098901  0.329670
# 3            73.00          9            0.098901  0.428571
# 4            52.00          9            0.098901  0.527473
# ..             ...        ...                 ...       ...
# 98           55.68          1            0.010989  2.318681
# 99           41.00          1            0.010989  2.329670
# 100          83.33          1            0.010989  2.340659
# 101          43.00          1            0.010989  2.351648
# 102          80.60          1            0.010989  2.362637
#
# [103 rows x 4 columns]

# %%
def Univariate(dataset,Quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=Quan)

    for columnName in Quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]= descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Greater"] = descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Min"] = dataset[columnName].min()
        descriptive[columnName]["Max"] = dataset[columnName].max()
    return descriptive

# %%
Univariate(dataset,Quan)

# %%
def OutlierDitector(Quan):
    LesserOut=[]
    GreaterOut=[]
    
    for columnName in Quan:
        if(descriptive[columnName]["Lesser"]>descriptive[columnName]["Min"]):
            LesserOut.append(columnName)
    
        if(descriptive[columnName]["Greater"]<descriptive[columnName]["Max"]):
            GreaterOut.append(columnName)
    return LesserOut, GreaterOut

# %%
OutlierDitector(Quan)
# Out:
# ([], [])

# %%
def ReplaceOutlier(LesserOut, GreaterOut):
    for columnName in LesserOut:
        dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
    
    for columnName in GreaterOut:
        dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]
    return LesserOut, GreaterOut

# %%
ReplaceOutlier(LesserOut, GreaterOut)
# Out:
# ([], [])

# %%
dir(dataset["ssc_p"])
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
dataset["ssc_p"].skew()
# Out:
# np.float64(-0.13264949031456927)

# %%
dataset["ssc_p"].kurtosis()
# Out:
# np.float64(-0.6075102066986688)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max","Skewness","Kurtosis"],columns=Quan)

for columnName in Quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]= descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]- descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"] = descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"] = dataset[columnName].min()
    descriptive[columnName]["Max"] = dataset[columnName].max()
    descriptive[columnName]["Skewness"]= dataset[columnName].skew()
    descriptive[columnName]["Kurtosis"]= dataset[columnName].kurtosis()

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# Min           1      40.89      42.75       50.0       50.0      51.21
# ...
